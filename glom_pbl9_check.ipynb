# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

import bokeh
import hvplot.pandas
import holoviews as hv

import bokeh.palettes
from bokeh.plotting import figure, show, output_notebook

import neuprint

import importlib
import lib as cl
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1235893e-21f9-45d8-838f-891dc331e917'>
#   <div id="a4f15494-2262-40a5-8127-b337f6ad2251" data-root-id="1235893e-21f9-45d8-838f-891dc331e917" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6Imt5bGllaHVjaEBiZXJrZWxleS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hL0FDZzhvY0tpVkJGeHFzT1JxRlhnNnNOX0xIWnd4RjRoWDJORWh4WFBpY2hDaEV1Qjdsei0yUT1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTkyMjI1NDAyMH0.WLushXPCMuxMHltv_LUpoVmhtGyZSTZw08ShIrEboLY"

c = neuprint.Client('neuprint.janelia.org', 'hemibrain:v1.2.1', TOKEN)

# %%
importlib.reload(cl)
from lib import syn_specs
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d0323ff3-2e73-4768-b86b-407e28a8b2f0'>
#   <div id="e0a854ae-9a7a-4187-b917-5ac205dd04cb" data-root-id="d0323ff3-2e73-4768-b86b-407e28a8b2f0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
del7_bid = 911470352 # L2R7

pbl_glom_syn = {}
for s in ['R', 'L']:
    for i in range(9):
        ss_l = syn_specs(target_neuron=del7_bid, scale='all', conn_type='pre', rois=[f'PB({s}{i+1})'], primary_only=False)
        pbl_glom_syn[f'PB({s}{i+1})'] = ss_l.fetch_syn_conns()
# Out:
# Fetching pre-synaptic connections...
#   0%|          | 0/17 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/66 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/179 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/106 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/99 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/35 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/54 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/29 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/16 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/43 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/35 [00:00<?, ?it/s]
# Fetching pre-synaptic connections...
#   0%|          | 0/49 [00:00<?, ?it/s]
# ...

# %%
print("Delta7 L2R7 per-glomeruli upstream (presynaptic) synapse counts:")
for k,v in pbl_glom_syn.items():
    print(f' * {k}:\t{len(v) if type(v)==pd.core.frame.DataFrame else 0}')
# Out:
# Delta7 L2R7 per-glomeruli upstream (presynaptic) synapse counts:
#  * PB(R1):	17
#  * PB(R2):	66
#  * PB(R3):	179
#  * PB(R4):	106
#  * PB(R5):	99
#  * PB(R6):	35
#  * PB(R7):	54
#  * PB(R8):	29
#  * PB(R9):	16
#  * PB(L1):	43
#  * PB(L2):	35
#  * PB(L3):	49
#  * PB(L4):	107
#  * PB(L5):	75
#  * PB(L6):	36
#  * PB(L7):	37
#  * PB(L8):	20
#  * PB(L9):	0

# %%
conns = cl.fetch_connectivity(target_scale='neuron', conn_scale='all', conn_type='pre', target_id=del7_bid, include_nonprimary=False)
print(conns)
print(sum(conns['weight']))
# Out:
#      bodyId_pre           instance_pre     type_pre  bodyId_post  \
# 8     541118908           EPG(PB08)_R3          EPG    911470352
# 130  5813080838           EPG(PB08)_R3          EPG    911470352
# 21    695956656           EPG(PB08)_R4          EPG    911470352
# 32    819828986           EPG(PB08)_L5          EPG    911470352
# 60    911574261  Delta7(PB15)_L1L9R8_R       Delta7    911470352
# 36    880880259    Delta7(PB15)_L4R5_R       Delta7    911470352
# 59    911574041    Delta7(PB15)_L2R7_R       Delta7    911470352
# 41    910442723    Delta7(PB15)_L4R5_R       Delta7    911470352
# 51    911129339    Delta7(PB15)_L4R5_R       Delta7    911470352
# 15    633546217           EPG(PB08)_R4          EPG    911470352
# 19    694920753           EPG(PB08)_R5          EPG    911470352
# 72    911919044    Delta7(PB15)_L6R3_L       Delta7    911470352
# 47    910783961    Delta7(PB15)_L3R6_R       Delta7    911470352
# ...

# %%
cnt = 0
for k,v in pbl_glom_syn.items():
    cnt += len(v) if type(v)==pd.core.frame.DataFrame else 0
print(cnt)
# Out:
# 1003

# %%
syn_l = syn_specs(target_neuron=del7_bid, scale='all', conn_type='pre', rois=['PB'])
top_conns_l = cl.skeleton_synapse_visualization(target_neuron=del7_bid, syn_classes=[syn_l])
print(top_conns_l)
# Out:
# Fetching pre-synaptic connections...
#   0%|          | 0/1003 [00:00<?, ?it/s]
#   <div id="e271132f-296d-433d-a464-6ce5e6ae87fd" data-root-id="bc2aa33e-d149-4ee6-ac77-86f44aa5d18c" style="display: contents;"></div>
# [type_pre
# Delta7         532
# EPG            389
# IbSpsP          20
# PFNv            15
# LPsP            12
# P1-9            11
# PFR_b            9
# PFGs             5
# EPGt             3
# SIFa             2
# PFNd             1
# PEN_a(PEN1)      1
# P6-8P9           1
# SpsP             1
# Name: count, dtype: int64]

# %%
syn_l = syn_specs(target_neuron=del7_bid, scale='all', conn_type='pre')
conn_df = syn_l.fetch_syn_conns()
print(conn_df)
# Out:
# Fetching pre-synaptic connections...
#   0%|          | 0/1007 [00:00<?, ?it/s]
#       bodyId_pre  bodyId_post roi_pre roi_post  x_pre  y_pre  z_pre  x_post  \
# 502    880880259    911470352      PB       PB  30922  14617  13427   30900
# 385    910796989    911470352      PB       PB  30614  14731  14222   30613
# 384    910801332    911470352      PB       PB  22841  14048  13868   22823
# 383    910801332    911470352      PB       PB  22748  14737  13679   22719
# 382    910801332    911470352      PB       PB  22353  15172  13897   22324
# 381    910801332    911470352      PB       PB  22333  14845  13670   22339
# 380    910801332    911470352      PB       PB  32345  14947  13683   32337
# 379    910801332    911470352      PB       PB  32157  14622  13382   32159
# 378    910801332    911470352      PB       PB  22491  15107  13921   22505
# 377    910801332    911470352      PB       PB  22693  14692  13653   22713
# ...

# %%
pbl9_syn = syn_specs(target_neuron=del7_bid, scale='all', conn_type='pre', rois=['PB(L9)'], primary_only=False)
conn_df = pbl9_syn.fetch_syn_conns()
print(conn_df)
# Out:
# Fetching pre-synaptic connections...
# No synapses match your source criteria
# None

# %%
importlib.reload(cl)

syn_l = syn_specs(target_neuron=del7_bid, scale='all', conn_type='pre', rois=['PB(L9)'], primary_only=False)
top_conns_l, points_l = cl.skeleton_synapse_visualization(target_neuron=del7_bid, syn_classes=[syn_l])
print(top_conns_l)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a27707af-e8cb-4c81-badc-ce153680c616'>
#   <div id="c167d1a9-3437-45de-9f50-1be226f62a80" data-root-id="a27707af-e8cb-4c81-badc-ce153680c616" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
