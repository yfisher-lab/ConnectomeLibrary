# %% [markdown]
# # Tutorial for ConnectomeLibrary

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

import bokeh
import hvplot.pandas
import holoviews as hv

import bokeh.palettes
from bokeh.plotting import figure, show, output_notebook

import neuprint

import importlib
import lib as cl

TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6Imt5bGllaHVjaEBiZXJrZWxleS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hL0FDZzhvY0tpVkJGeHFzT1JxRlhnNnNOX0xIWnd4RjRoWDJORWh4WFBpY2hDaEV1Qjdsei0yUT1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTkyMjI1NDAyMH0.WLushXPCMuxMHltv_LUpoVmhtGyZSTZw08ShIrEboLY"

c = neuprint.Client('neuprint.janelia.org', 'hemibrain:v1.2.1', TOKEN)

importlib.reload(cl)
from lib import syn_specs
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='cd0482ce-e914-4add-9d0c-b33629055cc7'>
#   <div id="e70c4938-53dc-41b6-8d8a-4a4bfb4793cd" data-root-id="cd0482ce-e914-4add-9d0c-b33629055cc7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Querying conectivity between two classes of neuron instances/subtypes/types
#
# This is done with the `fetch_connectivity()` function. All connections between the specified `target` and connecting (`conn`) classes of neurons will be returned as a pandas dataframe object.
# - Use the `scale` arguments to specify weather you're interested in an individual neuron ('neuron', eg 911901802), a subtype of neurons ('instance', eg 'Delta7(PB15)_L4R6_R') or an entire type of neurons ('type', eg 'Delta7')
#   - The `scale` argument determines the type of neuprint identifier you need to use for the corresponding `id` argument (type name, instance name, or bodyId number)
#     - NOTE: The identifiers provided to the `id` arguemnts (`target_id` and `conn_id`) must EXACTLY match the identifier for the given neuron class in the neuprint database
#     - For scales of 'type' and 'instance', the neuron class should be specified as a string, for the bodyId of individual neurons should be specified as an integer
# - Use the `conn_type` argument to specify weather you're interested in pre or post synaptic connections from the perspective of the target neuron class

# %%
# fetch connections between two types of neurons
type_conns = cl.fetch_connectivity(target_scale='type', conn_scale='type', conn_type='post', target_id='Delta7', conn_id='EPG')
print(type_conns)
# Out:
#       bodyId_pre           instance_pre type_pre  bodyId_post instance_post  \
# 168    910442782    Delta7(PB15)_L4R6_R   Delta7    634962055  EPG(PB08)_L4
# 587    911901802    Delta7(PB15)_L4R6_R   Delta7    634962055  EPG(PB08)_L4
# 498    911574041    Delta7(PB15)_L2R7_R   Delta7    697001770  EPG(PB08)_L2
# 643    911911004  Delta7(PB15)_L1L9R8_R   Delta7   1126647624  EPG(PB08)_R8
# 925    973959177    Delta7(PB15)_L6R3_L   Delta7   5813080838  EPG(PB08)_R3
# 174    910442782    Delta7(PB15)_L4R6_R   Delta7    910438331  EPG(PB08)_R6
# 320    911129204    Delta7(PB15)_L7R2_L   Delta7    695629525  EPG(PB08)_R2
# 595    911901802    Delta7(PB15)_L4R6_R   Delta7    942491983  EPG(PB08)_R6
# 453    911470352    Delta7(PB15)_L2R7_R   Delta7    912545106  EPG(PB08)_L2
# 703    911919044    Delta7(PB15)_L6R3_L   Delta7    541118908  EPG(PB08)_R3
# 556    911578496    Delta7(PB15)_L2R7_R   Delta7   1002852791  EPG(PB08)_R7
# ...

# %% [markdown]
# The `fetch_connectivity()` function returns connectivity data organized in a pandas DataFrame object with the number of synapses between each pair of connecting neurons of the specified target and connecting classes listed in the `weight` column.
#
# By default, the connections are listed in order of strongest connections (highest synapse counts) to weakest connections. You can sort the data using the `sort_values()` method and providing the name of the column you'd like to sort entries based on.

# %%
type_conns.sort_values('bodyId_pre', inplace=True)  # inplace argument means the original dataframe object will be sorted
print(type_conns)
# Out:
#       bodyId_pre           instance_pre type_pre  bodyId_post instance_post  \
# 17     734581598    Delta7(PB15)_L6R3_L   Delta7    912601268  EPG(PB08)_L6
# 0      734581598    Delta7(PB15)_L6R3_L   Delta7    416642425  EPG(PB08)_R4
# 11     734581598    Delta7(PB15)_L6R3_L   Delta7    695956656  EPG(PB08)_R4
# 1      734581598    Delta7(PB15)_L6R3_L   Delta7    449438847  EPG(PB08)_L3
# 25     734581598    Delta7(PB15)_L6R3_L   Delta7   5813080838  EPG(PB08)_R3
# 14     734581598    Delta7(PB15)_L6R3_L   Delta7    758419409  EPG(PB08)_L3
# 19     734581598    Delta7(PB15)_L6R3_L   Delta7   1004017998  EPG(PB08)_L7
# 21     734581598    Delta7(PB15)_L6R3_L   Delta7   1167995070  EPG(PB08)_L8
# 8      734581598    Delta7(PB15)_L6R3_L   Delta7    634962055  EPG(PB08)_L4
# 9      734581598    Delta7(PB15)_L6R3_L   Delta7    665314820  EPG(PB08)_L4
# 13     734581598    Delta7(PB15)_L6R3_L   Delta7    697001770  EPG(PB08)_L2
# ...

# %% [markdown]
# You can specify different scales for the target and connecting neuron classes (ie I want to see all inputs to EPG L4 neurons from any PEN_a neuron)

# %%
inst_type_conns = cl.fetch_connectivity(target_scale='instance', conn_scale='type', conn_type='post', target_id='EPG(PB08)_L4', conn_id='PEN_a(PEN1)')
print(inst_type_conns)
# Out:
#     bodyId_pre  instance_pre type_pre  bodyId_post    instance_post  \
# 18   665314820  EPG(PB08)_L4      EPG   5813080979  PEN_a(PB06a)_L5
# 4    634962055  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 25  5813022281  EPG(PB08)_L4      EPG   1002507131  PEN_a(PB06a)_R7
# 14   665314820  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 2    634962055  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 21  5813022281  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 5    634962055  EPG(PB08)_L4      EPG   1002507131  PEN_a(PB06a)_R7
# 11   665314820  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 16   665314820  EPG(PB08)_L4      EPG   1002507131  PEN_a(PB06a)_R7
# 24  5813022281  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 8    634962055  EPG(PB08)_L4      EPG   5813080979  PEN_a(PB06a)_L5
# 28  5813022281  EPG(PB08)_L4      EPG   5813080979  PEN_a(PB06a)_L5
# 3    634962055  EPG(PB08)_L4      EPG    847336755  PEN_a(PB06a)_R6
# ...

# %% [markdown]
# Each row in the dataframe represents a connection between an individual neuron of the target class to an individual neuron of the connecting neuron class (with the number of synapses between them given in the `weight` column).
#
# The length of the dataframe therefore represents the number of neuron pairs satisfying the given connectivity criteria.

# %%
print(len(inst_type_conns))
# Out:
# 29

# %% [markdown]
# You can restrict your search to only return results within a given ROI using the `roi` argument.

# %%
inst_type_conns_eb = cl.fetch_connectivity(target_scale='instance', conn_scale='type', conn_type='post', target_id='EPG(PB08)_L4', conn_id='PEN_a(PEN1)', rois=['EB', 'PB'])
print(len(inst_type_conns_eb), '\n')
print(inst_type_conns_eb)
# Out:
# 28
#
#     bodyId_pre  instance_pre type_pre  bodyId_post    instance_post  \
# 18   665314820  EPG(PB08)_L4      EPG   5813080979  PEN_a(PB06a)_L5
# 4    634962055  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 24  5813022281  EPG(PB08)_L4      EPG   1002507131  PEN_a(PB06a)_R7
# 14   665314820  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 2    634962055  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 21  5813022281  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 5    634962055  EPG(PB08)_L4      EPG   1002507131  PEN_a(PB06a)_R7
# 11   665314820  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 16   665314820  EPG(PB08)_L4      EPG   1002507131  PEN_a(PB06a)_R7
# 23  5813022281  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 8    634962055  EPG(PB08)_L4      EPG   5813080979  PEN_a(PB06a)_L5
# 27  5813022281  EPG(PB08)_L4      EPG   5813080979  PEN_a(PB06a)_L5
# 9    665314820  EPG(PB08)_L4      EPG    663190769  PEN_a(PB06a)_R6
# ...

# %% [markdown]
# You can also query within subregions of ROIs (ie individual glomeruli) or over multiple ROIs (ie the entire central complex) but this will also require setting the `include_nonprimary` argument to `True` as these regions are not primary ROIs within the hemibrain dataset

# %%
inst_type_conns_pbl4 = cl.fetch_connectivity(target_scale='instance', conn_scale='type', conn_type='post', target_id='EPG(PB08)_L4', conn_id='PEN_a(PEN1)', rois=['PB(L4)'], include_nonprimary=True)
print(inst_type_conns_pbl4)
# Out:
#    bodyId_pre  instance_pre type_pre  bodyId_post    instance_post  \
# 4   665314820  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 1   634962055  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 0   634962055  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 3   665314820  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 5  5813022281  EPG(PB08)_L4      EPG    757055317  PEN_a(PB06a)_L4
# 6  5813022281  EPG(PB08)_L4      EPG    849482511  PEN_a(PB06a)_L4
# 2   634962055  EPG(PB08)_L4      EPG   1508334312  PEN_a(PB06a)_L3
# 7  5813022281  EPG(PB08)_L4      EPG   1508334312  PEN_a(PB06a)_L3
#
#      type_post     roi  weight
# 4  PEN_a(PEN1)  PB(L4)      28
# 1  PEN_a(PEN1)  PB(L4)      26
# 0  PEN_a(PEN1)  PB(L4)      25
# 3  PEN_a(PEN1)  PB(L4)      22
# 5  PEN_a(PEN1)  PB(L4)      22
# 6  PEN_a(PEN1)  PB(L4)      17
# 2  PEN_a(PEN1)  PB(L4)       2
# 7  PEN_a(PEN1)  PB(L4)       1

# %% [markdown]
# You can query the connection dataframe to get a list of all connecting types, neurons (listed by neuprint bodyId), etc

# %%
downstream_instances = inst_type_conns_pbl4['instance_post'].unique()
downstream_neurons = inst_type_conns_pbl4['bodyId_post'].unique()
print(downstream_instances)
print(downstream_neurons)
# Out:
# ['PEN_a(PB06a)_L4' 'PEN_a(PB06a)_L3']
# [ 849482511  757055317 1508334312]

# %% [markdown]
# When querying connections on the neuron scale (for target neuron classes or connecting neuron classes), the neuprint neuron bodyId must be specified as an integer, not a string

# %%
neu_inst_conns = cl.fetch_connectivity(target_scale='neuron', conn_scale='instance', conn_type='post', target_id=880530613, conn_id='EPG(PB08)_R1')
print(neu_inst_conns)
# Out:
#    bodyId_pre         instance_pre type_pre  bodyId_post instance_post  \
# 0   880530613  Delta7(PB15)_L5R4_L   Delta7   5813014873  EPG(PB08)_R1
# 1   880530613  Delta7(PB15)_L5R4_L   Delta7   5813077544  EPG(PB08)_R1
#
#   type_post roi  weight
# 0       EPG  PB       3
# 1       EPG  PB       2

# %% [markdown]
# You can also get ALL pre/post synaptic connections to a given target neuron class by specifying a `conn_scale` of 'all'. In this case, do not specify a value for the `conn_id` argument

# %%
neu_conns = cl.fetch_connectivity(target_scale='neuron', conn_scale='all', conn_type='post', target_id=880530613)
print(neu_conns)
# Out:
#      bodyId_pre         instance_pre type_pre  bodyId_post  \
# 28    880530613  Delta7(PB15)_L5R4_L   Delta7    663562172
# 229   880530613  Delta7(PB15)_L5R4_L   Delta7   1631450739
# 74    880530613  Delta7(PB15)_L5R4_L   Delta7    881217171
# 101   880530613  Delta7(PB15)_L5R4_L   Delta7    911565319
# 76    880530613  Delta7(PB15)_L5R4_L   Delta7    881458145
# 68    880530613  Delta7(PB15)_L5R4_L   Delta7    880875861
# 188   880530613  Delta7(PB15)_L5R4_L   Delta7   1095275456
# 70    880530613  Delta7(PB15)_L5R4_L   Delta7    880875927
# 203   880530613  Delta7(PB15)_L5R4_L   Delta7   1200053009
# 66    880530613  Delta7(PB15)_L5R4_L   Delta7    880875742
# 5     880530613  Delta7(PB15)_L5R4_L   Delta7    446714544
# 104   880530613  Delta7(PB15)_L5R4_L   Delta7    911569552
# 22    880530613  Delta7(PB15)_L5R4_L   Delta7    632229278
# 121   880530613  Delta7(PB15)_L5R4_L   Delta7    911915224
# 198   880530613  Delta7(PB15)_L5R4_L   Delta7   1167282562
# ...

# %% [markdown]
# # Querying conectivity between multiple classes of neuron instances/subtypes/types

# %%
multi_conn = cl.fetch_connectivity_multi(target_scale='instance', target_id='Delta7(PB15)_L5R4_L', conn_type='post', conn_specs=[('type', 'EPG'), ('type', 'PEN_b(PEN2)')], rois=None, include_nonprimary=False)
print(multi_conn)
# Out:
#      bodyId_pre         instance_pre type_pre  bodyId_post    instance_post  \
# 16    880875736  Delta7(PB15)_L5R4_L   Delta7   1631450739  PEN_b(PB06b)_L5
# 43   5813048042  Delta7(PB15)_L5R4_L   Delta7   1631450739  PEN_b(PB06b)_L5
# 26    910796989  Delta7(PB15)_L5R4_L   Delta7   1631450739  PEN_b(PB06b)_L5
# 7     880530613  Delta7(PB15)_L5R4_L   Delta7   1631450739  PEN_b(PB06b)_L5
# 2     880530613  Delta7(PB15)_L5R4_L   Delta7    663562172  PEN_b(PB06b)_R4
# 28    910801332  Delta7(PB15)_L5R4_L   Delta7    569775058  PEN_b(PB06b)_R4
# 34    910801332  Delta7(PB15)_L5R4_L   Delta7   1631450739  PEN_b(PB06b)_L5
# 10    880875736  Delta7(PB15)_L5R4_L   Delta7    569775058  PEN_b(PB06b)_R4
# 37   5813048042  Delta7(PB15)_L5R4_L   Delta7    569775058  PEN_b(PB06b)_R4
# 29    910801332  Delta7(PB15)_L5R4_L   Delta7    663562172  PEN_b(PB06b)_R4
# 22    910796989  Delta7(PB15)_L5R4_L   Delta7    663562172  PEN_b(PB06b)_R4
# ...

# %% [markdown]
# # Visualizing connectivity

# %%
cl.visualize_conn(multi_conn, pre_scale='instance', post_scale='instance', sort_by='type', weight_col='weight', height=200, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
cl.visualize_conn(multi_conn, pre_scale='instance', post_scale='neuron', sort_by='type', weight_col='weight', height=200, width=900, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# # Normalize connection strengths between two classes of neurons

# %%
norm_conn = cl.normalize_connectivity(target_scale='instance', conn_scale='type', conn_type='pre', target_id='Delta7(PB15)_L5R4_L', conn_id='EPG', rois=None, norm_mode='syn_cnt')
print(norm_conn)
cl.visualize_conn(norm_conn, pre_scale='instance', post_scale='instance', sort_by='type', weight_col='norm_syn_cnt', height=500, width=300, x_ax_rot=60)
# Out:
#      bodyId_pre  instance_pre type_pre  bodyId_post        instance_post  \
# 25    572870540  EPG(PB08)_L1      EPG    880530613  Delta7(PB15)_L5R4_L
# 168  1447576662  EPG(PB08)_L1      EPG    880875736  Delta7(PB15)_L5R4_L
# 26    572870540  EPG(PB08)_L1      EPG    880875736  Delta7(PB15)_L5R4_L
# 198  5813077544  EPG(PB08)_R1      EPG    910796989  Delta7(PB15)_L5R4_L
# 178  5813014873  EPG(PB08)_R1      EPG    910796989  Delta7(PB15)_L5R4_L
# 196  5813077544  EPG(PB08)_R1      EPG    880530613  Delta7(PB15)_L5R4_L
# 176  5813014873  EPG(PB08)_R1      EPG    880530613  Delta7(PB15)_L5R4_L
# 27    572870540  EPG(PB08)_L1      EPG    910796989  Delta7(PB15)_L5R4_L
# 179  5813014873  EPG(PB08)_R1      EPG    910801332  Delta7(PB15)_L5R4_L
# 171  1447576662  EPG(PB08)_L1      EPG   5813048042  Delta7(PB15)_L5R4_L
# 177  5813014873  EPG(PB08)_R1      EPG    880875736  Delta7(PB15)_L5R4_L
# 199  5813077544  EPG(PB08)_R1      EPG    910801332  Delta7(PB15)_L5R4_L
# ...

# %%
norm_conn = cl.normalize_connectivity(target_scale='instance', conn_scale='type', conn_type='pre', target_id='Delta7(PB15)_L5R4_L', conn_id='EPG', rois=None, norm_mode='syn_tot')
print(norm_conn)
# Out:
#      bodyId_pre  instance_pre type_pre  bodyId_post        instance_post  \
# 25    572870540  EPG(PB08)_L1      EPG    880530613  Delta7(PB15)_L5R4_L
# 168  1447576662  EPG(PB08)_L1      EPG    880875736  Delta7(PB15)_L5R4_L
# 26    572870540  EPG(PB08)_L1      EPG    880875736  Delta7(PB15)_L5R4_L
# 198  5813077544  EPG(PB08)_R1      EPG    910796989  Delta7(PB15)_L5R4_L
# 178  5813014873  EPG(PB08)_R1      EPG    910796989  Delta7(PB15)_L5R4_L
# 196  5813077544  EPG(PB08)_R1      EPG    880530613  Delta7(PB15)_L5R4_L
# 176  5813014873  EPG(PB08)_R1      EPG    880530613  Delta7(PB15)_L5R4_L
# 27    572870540  EPG(PB08)_L1      EPG    910796989  Delta7(PB15)_L5R4_L
# 179  5813014873  EPG(PB08)_R1      EPG    910801332  Delta7(PB15)_L5R4_L
# 171  1447576662  EPG(PB08)_L1      EPG   5813048042  Delta7(PB15)_L5R4_L
# 177  5813014873  EPG(PB08)_R1      EPG    880875736  Delta7(PB15)_L5R4_L
# 199  5813077544  EPG(PB08)_R1      EPG    910801332  Delta7(PB15)_L5R4_L
# ...

# %% [markdown]
# # Normalize connection strengths between multiple classes of neurons
#
# --> Coming soon...

# %% [markdown]
# # Querying synaptic connections to/from an individual neuron

# %%
target = 880880259
s1 = syn_specs(target_neuron=target, scale='all', conn_type='pre', rois=['PB'], lable_res=None, top=None, primary_only=True)
#s2 = syn_specs(target_neuron=target, scale='type', conn_type='post', conn_id='PEN_b(PEN2)', rois=['PB'], lable_res=None, top=None, primary_only=True)

# Plot the specified synapse classes
#top_conns_1 = cl.skeleton_synapse_visualization(target_neuron=target, syn_classes=[s1], paletts=[bokeh.palettes.YlOrRd9, bokeh.palettes.YlGnBu4], loop_colors=True)
top_conns_1 = cl.skeleton_synapse_visualization(target_neuron=target, syn_classes=[s1], paletts=[bokeh.palettes.YlOrRd9], loop_colors=True)
print(top_conns_1)
# Out:
# Fetching pre-synaptic connections...
#   0%|          | 0/1146 [00:00<?, ?it/s]
#   <div id="a4b5351c-649f-4bf1-b809-922b170c855e" data-root-id="2641b27c-43d4-42ad-a5d5-69ee435f2e47" style="display: contents;"></div>
# [type_pre
# Delta7    650
# EPG       388
# LPsP       19
# EPGt       18
# IbSpsP     15
# PFNv       13
# P1-9       12
# PFR_b       9
# PFGs        6
# SpsP        6
# PFNa        4
# SIFa        2
# PFL2        1
# P6-8P9      1
# Name: count, dtype: int64]

# %%
target = 880880259
s1 = syn_specs(target_neuron=target, scale='type', conn_type='pre', conn_id='EPG', rois=['PB(R1)'], lable_res=None, top=None, primary_only=False)

top_conns_1 = cl.skeleton_synapse_visualization(target_neuron=target, syn_classes=[s1], paletts=[bokeh.palettes.YlOrRd9], loop_colors=True)
print(top_conns_1)
# Out:
# Fetching pre-synaptic connections...
#   0%|          | 0/57 [00:00<?, ?it/s]
#   <div id="b0d89cd4-3c71-40cb-ad5a-b8cdf3eaa50a" data-root-id="51594cd8-a684-4e65-ad21-dc2b563dfd1b" style="display: contents;"></div>
# [instance_pre
# EPG(PB08)_R1    54
# EPG(PB08)_L1     3
# Name: count, dtype: int64]

# %%
s1 = syn_specs(target_neuron=target, scale='type', conn_type='pre', conn_id='EPG', rois=['PB(R1)'], lable_res=None, top=None, primary_only=False)
s1_conns_df = s1.fetch_syn_conns()
print(s1_conns_df)
# Out:
# Fetching pre-synaptic connections...
#   0%|          | 0/57 [00:00<?, ?it/s]
#     bodyId_pre  bodyId_post           roi_pre          roi_post  x_pre  y_pre  \
# 0   5813077544    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25653  14234
# 30  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25509  13961
# 31  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25734  14061
# 32  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25676  13876
# 33  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25545  13693
# 34  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  26035  13565
# 35  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25627  13557
# 36  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25926  14049
# 37  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25639  13892
# 38  5813014873    880880259  [CX, PB, PB(R1)]  [CX, PB, PB(R1)]  25805  14884
# ...

# %% [markdown]
# # Visualizing synaptic connections
